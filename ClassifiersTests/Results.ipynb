# %% [markdown]
# # Experiment #1

# %% [markdown]
# ## MLP Classifier Results

# %% [markdown]
# Embeddings were genereated using the following prompt:

# %% [markdown]
#  f"USER:  You are an expert AI content moderator for a major social media platform, specializing in identifying "
#             f"hate speech in multimodal content (images and text). Your primary task is to classify the following meme.\n"
#             f"Definition of Hate Speech: Content that promotes or incites discrimination, dehumanization, violence, "
#             f"or severe harassment against individuals or groups based on protected characteristics such as race, "
#             f"ethnicity, nationality, religion, gender, sexual orientation, disability, or veteran status. "
#             f"This includes offensive stereotypes and targeted attacks that meet this criteria."
#             f"Examples of Classification:\n"
#             f"- Meme (Image: showing a derogatory caricature, Text: 'They don't belong here.'). Is it Hateful? -> Yes\n"
#             f"- Meme (Image: two cats fighting, Text: 'Cats are better than dogs.'). Is it Hateful? -> No\n"
#             f"- Meme (Image: a person of color, Text: 'All [racial slur] should be removed.'). Is it Hateful? -> Yes\n"
#             f"- Meme (Image: political figure, Text: 'This politician is incompetent.'). Is it Hateful? -> No\n"
#             f"Meme (Image: person looking sad, Text: 'Just a bad joke.'). Is it Hateful? -> No (Even if offensive, if it doesn't meet the hate speech definition)\n\n"
#             f"Now, examine the following meme, including its image and text: \"{meme_text}\"\n"
#             f"Based on the definition and examples, is this meme Hateful? Answer 'Yes' or 'No' only.\n"
#             f"ASSISTANT:"

# %% [markdown]
# Additional info: Mean intra-class distance: 0.0525
# Mean inter-class distance: 0.0534
# Separation gap: 0.0009

# %% [markdown]
# ### MLP Classifier build:
#             "hidden_layer_sizes": [1024, 512, 256],
#             "early_stopping": True,
#             "n_iter_no_change": 5,
#             "max_iter": 100,

# %% [markdown]
# ### Results

# %% [markdown]
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.61       210
#            1       0.59      0.49      0.54       208
#
#     accuracy                           0.58       418
#    macro avg       0.58      0.58      0.58       418
# weighted avg       0.58      0.58      0.58       418
#
# AUROC: 0.6114239926739926
# Test:
#               precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65       510
#            1       0.63      0.47      0.54       490
#
#     accuracy                           0.60      1000
#    macro avg       0.61      0.60      0.60      1000
# weighted avg       0.61      0.60      0.60      1000
#
# AUROC: 0.6560504201680671

# %% [markdown]
# ### Classifier build:

# %% [markdown]
# "hidden_layer_sizes": [512, 256],
#             "early_stopping": True,
#             "n_iter_no_change": 10,
#             "max_iter": 300,
#         }

# %% [markdown]
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.54      0.77      0.63       210
#            1       0.58      0.33      0.42       208
#
#     accuracy                           0.55       418
#    macro avg       0.56      0.55      0.53       418
# weighted avg       0.56      0.55      0.53       418
#
# AUROC: 0.5957417582417581
# Test:
#               precision    recall  f1-score   support
#
#            0       0.59      0.85      0.69       510
#            1       0.70      0.38      0.49       490
#
#     accuracy                           0.62      1000
#    macro avg       0.65      0.61      0.59      1000
# weighted avg       0.64      0.62      0.59      1000
#
# AUROC: 0.6790436174469788

# %% [markdown]
# The embeddings were too similar.

# %% [markdown]
# ## XGBoost Classifier Results
# Classifier build:
# params={
#             "n_estimators": 500,
#             "max_depth": 6,
#             "early_stopping_rounds": 10,
#             "learning_rate": 0.05,
#         }

# %% [markdown]
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.55      0.70      0.62       210
#            1       0.59      0.43      0.50       208
#
#     accuracy                           0.57       418
#    macro avg       0.57      0.57      0.56       418
# weighted avg       0.57      0.57      0.56       418
#
# AUROC: 0.5821886446886446
# Test:
#               precision    recall  f1-score   support
#
#            0       0.58      0.78      0.66       510
#            1       0.64      0.41      0.50       490
#
#     accuracy                           0.60      1000
#    macro avg       0.61      0.60      0.58      1000
# weighted avg       0.61      0.60      0.59      1000
#
# AUROC: 0.628047218887555

# %% [markdown]
# # Experiment #2

# %% [markdown]
# Prompt: prompt = (
#             f"A chat between a curious user and an AI assistant specialized that detects hate speech in memes.\n"
#             f"USER: \n{meme_text}\n"
#             f"Is this meme hateful? Answer only 'Yes' or 'No'.\n"
#             f"ASSISTANT:"
#         )
#
# Mean intra-class distance: 0.0687
# Mean inter-class distance: 0.0696
# Separation gap: 0.0009

# %% [markdown]
# ## XGBoost Classifier Results (Same architecture as before)
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.57      0.74      0.64       210
#            1       0.62      0.43      0.51       208
#
#     accuracy                           0.59       418
#    macro avg       0.59      0.59      0.58       418
# weighted avg       0.59      0.59      0.58       418
#
# AUROC: 0.597275641025641
# Test:
#               precision    recall  f1-score   support
#
#            0       0.57      0.79      0.66       510
#            1       0.63      0.38      0.48       490
#
#     accuracy                           0.59      1000
#    macro avg       0.60      0.58      0.57      1000
# weighted avg       0.60      0.59      0.57      1000
#
# AUROC: 0.6095258103241297

# %% [markdown]
# ## MLP Classifier Results

# %% [markdown]
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.54      0.78      0.64       210
#            1       0.60      0.34      0.43       208
#
#     accuracy                           0.56       418
#    macro avg       0.57      0.56      0.53       418
# weighted avg       0.57      0.56      0.53       418
#
# AUROC: 0.602930402930403
# Test:
#               precision    recall  f1-score   support
#
#            0       0.58      0.81      0.68       510
#            1       0.67      0.39      0.49       490
#
#     accuracy                           0.60      1000
#    macro avg       0.62      0.60      0.58      1000
# weighted avg       0.62      0.60      0.59      1000
#
# AUROC: 0.670344137655062

# %% [markdown]
# # Experiment #3

# %% [markdown]
# prompt = f"""
#         You are a highly capable AI content moderator tasked with detecting **hate speech in memes**, combining **image and text analysis**.
#
#         **Definition of Hate Speech**:
#         Hate speech includes content that:
#         - Promotes or incites discrimination, dehumanization, violence, or severe harassment,
#         - Targets people based on race, ethnicity, nationality, religion, gender, sexual orientation, disability, or veteran status,
#         - Uses offensive slurs, negative stereotypes, or calls to harm.
#
#         **Your task**:
#         Analyze the following meme (both the image and text). Based on the hate speech definition, classify it as **Hateful** or **Non-Hateful**. Answer using only one word: `"Yes"` if hateful, or `"No"` if not.
#
#         **Examples**:
#         1. Image: a racist caricature, Text: "They are all criminals." → **Yes**
#         2. Image: two dogs fighting, Text: "Dogs rule, cats drool." → **No**
#         3. Image: a transgender person, Text: "They shouldn't exist." → **Yes**
#         4. Image: a politician, Text: "I think she's wrong." → **No**
#         5. Image: a person crying, Text: "This is me after finals." → **No**
#
#         Now evaluate the following meme:
#         Image:
#         Text: "{meme_text}"
#
#         **Is this meme Hateful? Answer only 'Yes' or 'No'.**
#         ASSISTANT:"""

# %% [markdown]
# Mean intra-class distance: 0.0591
# Mean inter-class distance: 0.0597
# Separation gap: 0.0006

# %% [markdown]
# ## MLP Classifier Results
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.53      0.71      0.61       210
#            1       0.56      0.37      0.44       208
#
#     accuracy                           0.54       418
#    macro avg       0.55      0.54      0.53       418
# weighted avg       0.55      0.54      0.53       418
#
# AUROC: 0.6008699633699633
# Test:
#               precision    recall  f1-score   support
#
#            0       0.58      0.77      0.66       510
#            1       0.64      0.42      0.51       490
#
#     accuracy                           0.60      1000
#    macro avg       0.61      0.60      0.59      1000
# weighted avg       0.61      0.60      0.59      1000
#
# AUROC: 0.6573869547819128

# %% [markdown]
# ## XGBoost Classifier Results
# Validation:
#               precision    recall  f1-score   support
#
#            0       0.53      0.70      0.60       210
#            1       0.55      0.37      0.44       208
#
#     accuracy                           0.53       418
#    macro avg       0.54      0.53      0.52       418
# weighted avg       0.54      0.53      0.52       418
#
# AUROC: 0.5550824175824176
# Test:
#               precision    recall  f1-score   support
#
#            0       0.56      0.76      0.64       510
#            1       0.60      0.37      0.46       490
#
#     accuracy                           0.57      1000
#    macro avg       0.58      0.57      0.55      1000
# weighted avg       0.58      0.57      0.55      1000
#
# AUROC: 0.6053381352541016
